# %% [markdown]
# # Newton's Foward Difference Interpolating Polynomials

# %% [markdown]
# Take only a small sample of point

# %% [markdown]
# Name : Mukesh Tiwari
# Date : 03/04/2022

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
#input data

xval = np.linspace(-5,5,18)

#yval = np.e**xval
yval = np.sin(xval) + 0.5 * np.cos(xval) +  0.7 * np.sin(2*xval)

# %%
xval
# Out:
# array([-5.        , -4.41176471, -3.82352941, -3.23529412, -2.64705882,
#        -2.05882353, -1.47058824, -0.88235294, -0.29411765,  0.29411765,
#         0.88235294,  1.47058824,  2.05882353,  2.64705882,  3.23529412,
#         3.82352941,  4.41176471,  5.        ])

# %%
yval
# Out:
# array([ 1.48157015,  0.41112279, -0.44294633, -0.53465775, -0.32985658,
#        -0.53789656, -1.08431718, -1.14144885, -0.199792  ,  1.15685031,
#         1.77678473,  1.18435764,  0.06901225, -0.55033348, -0.46095548,
#        -0.33340711, -0.70723933, -1.19790796])

# %%
#defining constants

h = xval[1] - xval[0]   
n = len(yval)
h
# Out:
# 0.5882352941176467

# %%
#Implementing forward differnce operator

def fdiff(y, n ,i):
    if n == 0:
        return y[i]
    
    return fdiff(y,n-1,i+1) - fdiff(y,n-1,i)

# %%
#implementing D

def d(x,i):
    ans = 1
    for j in range(0,i):
        ans = ans * (x - xval[j])
    return ans

# %%
d(0,3)
# Out:
# 84.34256055363322

# %%
#Implementing p for a
def p(i):
    ans = 1
    for j in range(0,i):
        ans = ans * (p - j)
    return ans

# %%
def coeff(y , order):
    n = len(y)
    c = []
    for i in range(0,order):
        c.append(fdiff(y,i,0) / (math.factorial(i) * h**i))
    return c

# %%
def pol(coeff , x):
    val = 0
    n = len(coeff)
    for i in range(0,n):
        val = val + coeff[i] * d(x,i)
    return val

# %%
co = coeff(yval[2:],4)

# %%
fval = [np.sin(i) + 0.5 * np.cos(i) +  0.7 * np.sin(2*i) for i in np.linspace(-5,5,200)]
pval = [pol(co , i) for i in np.linspace(-5,5,200)]
fig , ax = plt.subplots()
ax.plot(xval,yval , 'ko')
ax.set_xlim([-6, 6])
ax.set_ylim([-10, 10])
ax.plot(np.linspace(-5,5,200), pval , 'blue')
ax.plot(np.linspace(-5,5,200) , fval , 'red')
plt.savefig("image.png")
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fval = [np.sin(i) + 0.5 * np.cos(i) +  0.7 * np.sin(2*i) for i in np.linspace(-5,5,200)]
xval_i = xval
yval_i = yval
for pi in range(0,len(yval) - 4):
    xval = xval_i[pi:]
    yval = yval_i[pi:]
    co = coeff(yval,4)  
    pval = [pol(co , i) for i in np.linspace(-5,5,200)]
    fig , ax = plt.subplots()
    ax.plot(xval_i,yval_i , 'ko')
    ax.set_xlim([-6, 6])
    ax.set_ylim([-7, 7])
    ax.plot(np.linspace(-5,5,200), pval , 'blue' )
    ax.plot(np.linspace(-5,5,200) , fval , 'red' )
    ax.set_title("polynomial approximation of order 4 of \n $ f(x) = \sin(x) + 0.5\cos(x) + 0.7\sin(2x)$")
    plt.savefig("image{pi}.png".format(pi=pi))
    fig.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
li = [0,1,2,3,4]

# %%
li[2:]
# Out:
# [2, 3, 4]
