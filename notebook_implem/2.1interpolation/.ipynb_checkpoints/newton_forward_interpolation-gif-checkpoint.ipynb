# %% [markdown]
# # Newton's Foward Difference Interpolating Polynomials

# %% [markdown]
# Name : Mukesh Tiwari
# Date : 03/04/2022

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
#input data

xval = np.linspace(-5,5,10)

#yval = np.e**xval
yval = np.sin(xval) + 0.5 * np.cos(xval) +  0.7 * np.sin(2*xval)

# %%
xval
# Out:
# array([-5.        , -3.88888889, -2.77777778, -1.66666667, -0.55555556,
#         0.55555556,  1.66666667,  2.77777778,  3.88888889,  5.        ])

# %%
yval
# Out:
# array([ 1.48157015, -0.38507516, -0.357544  , -0.90987216, -0.72994615,
#         1.57955371,  0.81414861, -0.57700214, -0.34845402, -1.19790796])

# %%
#defining constants

h = xval[1] - xval[0]   
n = len(yval)
h
# Out:
# 1.1111111111111112

# %%
#Implementing forward differnce operator

def fdiff(y, n ,i):
    if n == 0:
        return y[i]
    
    return fdiff(y,n-1,i+1) - fdiff(y,n-1,i)

# %%
#implementing D

def d(x,i):
    ans = 1
    for j in range(0,i):
        ans = ans * (x - xval[j])
    return ans

# %%
d(0,3)
# Out:
# 54.01234567901234

# %%
#Implementing p for a
def p(i):
    ans = 1
    for j in range(0,i):
        ans = ans * (p - j)
    return ans

# %%
def coeff(y):
    n = len(y)
    c = []
    for i in range(0,n):
        c.append(fdiff(y,i,0) / (math.factorial(i) * h**i))
    return c

# %%
def pol(coeff , x):
    val = 0
    for i in range(0,n):
        val = val + coeff[i] * d(x,i)
    return val

# %%
co = coeff(yval)

# %%
fval = [np.sin(i) + 0.5 * np.cos(i) +  0.7 * np.sin(2*i) for i in np.linspace(-5,5,200)]
pval = [pol(co , i) for i in np.linspace(-5,5,200)]
fig , ax = plt.subplots()
ax.plot(xval,yval , 'ko')
ax.plot(np.linspace(-5,5,200), pval , 'blue')
ax.plot(np.linspace(-5,5,200) , fval , 'red')

fig.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
