# %%
import sympy as sy
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
x = sy.Symbol('x')

# %%
f = (2*x**3+1 ) / (3*x**2 - 1)

# %%
f
# Out:
# (2*x**3 + 1)/(3*x**2 - 1)

# %%
f_diff = sy.diff(f,x)

# %%
sy.simplify(f_diff)
# Out:
# 6*x*(x**3 - x - 1)/(9*x**4 - 6*x**2 + 1)

# %%
sy.plot(f_diff , (x , 0 , 2), title='phi_derivative' , ylim = (-100 , 100) )
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # for some reason the root of derivative of phi(x) is the root of f(x) f the phi(x) is determined by the newton rhapson method. HOW????

# %%
f_diff.subs(x,1.1)
# Out:
# -0.733768017464471

# %%
x_vals = [1.1 + 0.9*np.random.random() for _ in range(0 ,1000)]
y_vals = [f_diff.subs(x,i) for i in x_vals]

good = filter(lambda x : abs(x) < 1 , y_vals)
print(len(list(good)))
# Out:
# 1000
