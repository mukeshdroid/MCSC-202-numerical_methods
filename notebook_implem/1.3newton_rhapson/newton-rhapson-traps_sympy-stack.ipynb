# %% [markdown]
# # Loops in Newton-Rhapson using sympy
# [hint taken from this ques in stack exhange](https://math.stackexchange.com/questions/2407659/why-does-the-newton-raphson-method-not-converge-for-some-functions)

# %% [markdown]
# Date    : 02/01/2022
#
# Author  : Mukesh Tiwari

# %%
import sympy as sy
from sympy.solvers import solve
from sympy import Eq , lambdify
import scipy as sp
import scipy.optimize
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib notebook

# %%
x = sy.Symbol('x')
f = -3.55*x**3 + 1.1 * x**2 + 0.765*x - 0.74 
f
# Out:
# -3.55*x**3 + 1.1*x**2 + 0.765*x - 0.74

# %%
f_der = sy.diff(f,x)
f_der
# Out:
# -10.65*x**2 + 2.2*x + 0.765

# %%
g = x - f/f_der
sy.simplify(g)
# Out:
# (7.1*x**3 - 1.1*x**2 - 0.74)/(10.65*x**2 - 2.2*x - 0.765)

# %%
sy.simplify(g.subs(x,g))
# Out:
# (238.607333333333*x**13 - 264.932555555555*x**12 + 90.4497925925926*x**11 - 155.372794444444*x**10 + 143.636029097548*x**9 - 17.2588378110972*x**8 - 13.2032285917966*x**7 - 0.877943456984391*x**6 + 1.73119881875227*x**5 - 0.110419774634073*x**4 - 0.0212409432981529*x**3 + 0.0200469843048065*x**2 - 0.00378312552124225*x - 0.00101013133071769)/(536.8665*x**12 - 665.412*x**11 + 145.4763375*x**10 + 11.2494055555555*x**9 + 62.506883135759*x**8 - 30.7649803896199*x**7 - 0.475146330305551*x**6 + 1.0405674184414*x**5 - 0.367459561466333*x**4 + 0.186066772342876*x**3 + 0.0302787802692743*x**2 - 0.0109523223119016*x - 0.00153395395277492)

# %%
phi1 = sy.simplify(g.subs(x,(g.subs(x,g))))
phi1
# Out:
# (13889039150.9727*x**59 - 79796768361.5468*x**58 + 207899023437.326*x**57 - 367533104818.138*x**56 + 581187800884.246*x**55 - 854620817747.856*x**54 + 1026289659443.71*x**53 - 968714532243.065*x**52 + 798321474579.981*x**51 - 648356673632.552*x**50 + 496793115826.846*x**49 - 327821865300.675*x**48 + 194714949001.299*x**47 - 114632278951.731*x**46 + 63427982389.1676*x**45 - 30455215118.0091*x**44 + 14035822940.5485*x**43 - 6666013905.53415*x**42 + 2652596551.20856*x**41 - 811406779.768122*x**40 + 300489068.655052*x**39 - 134171602.565836*x**38 + 29609971.6093794*x**37 + 1799804.34670286*x**36 - 272654.13214379*x**35 - 731779.241301933*x**34 - 3597.39195556237*x**33 + 139202.024922645*x**32 - 55715.0351318519*x**31 + 11316.9153546865*x**30 + 3071.21897102499*x**29 - 2225.06814700193*x**28 + 38.8652293827419*x**27 + 115.433912651905*x**26 + 10.0373028708399*x**25 - 5.90910515599116*x**24 - 0.935957085609683*x**23 + 1.02151427258513*x**22 - 0.449788652168204*x**21 - 0.0516446332582467*x**20 + 0.0758201891156323*x**19 - 0.00889069626098389*x**18 - 0.0032462517068903*x**17 + 0.00130703898865968*x**16 - 0.000202956348866161*x**15 - 6.28975175357298e-5*x**14 + 2.79019214665969e-5*x**13 + 1.09786001495558e-7*x**12 - 1.07768020390868e-6*x**11 + 1.5214025444329e-7*x**10 - 1.54555152543278e-
22 - 0.449788652168204*x**21 - 0.0516446332582467*x**20 + 0.0758201891156323*x**19 - 0.00889069626098389*x**18 - 0.0032462517068903*x**17 + 0.00130703898865968*x**16 - 0.000202956348866161*x**15 - 6.28975175357298e-5*x**14 + 2.79019214665969e-5*x**13 + 1.09786001495558e-7*x**12 - 1.07768020390868e-6*x**11 + 1.5214025444329e-7*x**10 - 1.54555152543278e-9*x**9 - 1.04127611736296e-8*x**8 + 1.51541607835684e-9*x**7 + 4.05068772180219e-10*x**6 - 5.04609706924569e-11*x**5 - 9.18023316554672e-12*x**4 + 6.93909917348477e-13*x**3 + 1.01640677085777e-13*x**2 - 5.64328855370513e-15*x - 6.66504078339878e-16)/(46875507134.5559*x**58 - 280812897200.333*x**57 + 738398079126.666*x**56 - 1164317193206.56*x**55 + 1362917415675.1*x**54 - 1471827948912.9*x**53 + 1551167209061.7*x**52 - 1425364249528.99*x**51 + 1100345827318.68*x**50 - 779910689611.227*x**49 + 534978109462.157*x**48 - 331523463193.246*x**47 + 183186313950.471*x**46 - 100428435757.736*x**45 + 53795578281.6238*x**44 - 24036559679.8546*x**43 + 9362207852.35434*x**42 - 4222156519.76849*x**41 + 1869661540.28888*x**40 - 518668193.910238*x**39 + 91896723.9095646*x**38 - 42386302.8788683*x**37 + 18624102.2815641*x**36 - 590704.015637198*x**35 - 1598582.7253513*x**34 + 367184.114603588*x**33 - 5618.68512854041*x**32 - 34558.0809229431*x**31 + 5816.7336656553*x**30 + 10893.9048135811*x**29 - 4319.98565226703*x**28 - 270.59344521908*x**27 + 327.672349295242*x**26 - 45.2430625100307*x**25 - 1.41685110747727*x**24 + 4.74065699163722*x**23 + 0.218293936063287*x**22 - 1.05988193880965*x**21 + 0.0752745826732667*x**20 + 0.099665553387882*x**19 - 0.0252086121951445*x**18 + 0.000877780091128601*x**17 + 0.0018565095658831*x**16 - 0.000694435995174221*x**15 - 1.25986956692003e-5*x**14 + 4.30533652107152e-5*x**13 - 5.70203033922306e-6*x**12 - 5.29211356656409e-7*x**11 + 4.11539003428922e-7*x**10 - 5.87651224799265e-8*x**9 - 1.50379751947003e-8*x**8 + 3.40339271626735e-9*x**7 + 2.66824246506298e-10*x**6 - 9.33060406917341e-11*x**5 + 1.0311919549553e-12*x**4 + 2.11965004051721e-12*x**3 - 5.81948669778701e-14*x**2 - 3.74785802091229e-14*x - 1.97743375688576e-15)

# %%
func = sy.lambdify(x,eq1.lhs)
func
# Out:
# <function _lambdifygenerated(x)>

# %%
func(-0.5846)
# Out:
# -0.023534534293901288

# %%
xval = np.linspace(-2,3,100000)
yval = func(xval)
xaxis = np.zeros(len(xval))
plt.plot(xval,yval)
plt.plot(xval,xaxis)
plt.show()
# Out:
# <div id='5c8601c6-1f1a-4211-833d-56f84a5f8f7c'></div>

# %%
sol = sp.optimize.root(func, -0.517 )

# %%
sol.x
# Out:
# array([-0.60813453])

# %%
sol1 = sp.optimize.root(func, 0.55)

sol1.x
# Out:
# array([0.54999991])

# %%
sy.solve(eq1, x)

# %%
f = sp.lambdify(x, sp.nsolve(),"numpy")
