# %% [markdown]
# # Python Assignment I

# %%
from IPython.display import Image
import math
import numpy as np
from tabulate import tabulate

import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator

# %% [markdown]
# ### Ques 1

# %%
from IPython.display import Image
Image('/content/drive/MyDrive/MCSC-202-Numerical/q1.png')

# %%
#given
h_o = 1.2
v_o = 5.4
g = 9.8

def height(t):
  h = h_o + v_o * t - 0.5 * g * t * t
  return h

def velocity(t):
  v = v_o - g * t
  return v

# %%
print('The height and velocity after 0.5s is %5.3f' %height(0.5) , 'm and ' , velocity(0.5) , 'm/s' )
# Out:
# The height and velocity after 0.5s is 2.675 m and  0.5 m/s

# %%
print('The height and velocity after 1s is %5.3f' %height(1) , 'm and ' , velocity(1) , 'm/s' )
# Out:
# The height and velocity after 1s is 1.700 m and  -4.4 m/s

# %%
print('The height and velocity after 2s is %5.3f' %height(2) , 'm and ' , round(velocity(2),3) , 'm/s' )
# Out:
# The height and velocity after 2s is -7.600 m and  -14.2 m/s

# %% [markdown]
# ### Ques 2

# %%
Image('/content/drive/MyDrive/MCSC-202-Numerical/q2.png')

# %%
#2. i)

(2 + math.exp(2.8)) / (math.sqrt(13) - 2)
# Out:
# 11.488045914800647

# %%
#2. ii)

(1 - (1 + math.log(2))**(-3.5)) / (1 + math.sqrt(5))
# Out:
# 0.26008973689431575

# %%
#2. iii)

math.sin((2 - math.sqrt(2))/(2 + math.sqrt(2)))
# Out:
# 0.17073234104506005

# %% [markdown]
# ### Ques 3

# %%
Image('/content/drive/MyDrive/MCSC-202-Numerical/q3.png')

# %%
#without any packages
arr = [ i * (29/8) for i in range(0 , 9)]
arr_sq = [i**2 for i in arr]

arr_add = [i + i for i in arr]
arr_mul = [i * 2 for i in arr]

print('array = ' , arr)
print('array squared = ' , arr_sq)
print('array added twice = ' , arr_add)
print('array multiplied = ' , arr_mul)
# Out:
# array =  [0.0, 3.625, 7.25, 10.875, 14.5, 18.125, 21.75, 25.375, 29.0]
# array squared =  [0.0, 13.140625, 52.5625, 118.265625, 210.25, 328.515625, 473.0625, 643.890625, 841.0]
# array added twice =  [0.0, 7.25, 14.5, 21.75, 29.0, 36.25, 43.5, 50.75, 58.0]
# array multiplied =  [0.0, 7.25, 14.5, 21.75, 29.0, 36.25, 43.5, 50.75, 58.0]

# %%
#using numpy
arr = np.linspace(0,29,9)
arr_sq = arr**2

arr_add = arr + arr
arr_mul = arr * 2

print('array = ' , arr)
print('array squared = ' , arr_sq)
print('array added twice = ' , arr_add)
print('array multiplied = ' , arr_mul)
# Out:
# array =  [ 0.     3.625  7.25  10.875 14.5   18.125 21.75  25.375 29.   ]
# array squared =  [  0.        13.140625  52.5625   118.265625 210.25     328.515625
#  473.0625   643.890625 841.      ]
# array added twice =  [ 0.    7.25 14.5  21.75 29.   36.25 43.5  50.75 58.  ]
# array multiplied =  [ 0.    7.25 14.5  21.75 29.   36.25 43.5  50.75 58.  ]

# %% [markdown]
# ### Ques 4

# %%
Image('/content/drive/MyDrive/MCSC-202-Numerical/q4.png')

# %%
Image('/content/drive/MyDrive/MCSC-202-Numerical/q4a.png')

# %%
#given values
h_o = 10
g = 9.8

#function to calculate the time given the height
def time_givenh(h):
  t = np.sqrt((h_o - h)/(0.5 * g))
  return t

#array of height 
h_array = np.linspace(10,0,21)

#array of time corresponding the given height
time = np.array([time_givenh(i) for i in h_array])

#array of average velocity using finite approximation
av_vel_array =  [ 0.5 / (time[i + 1] - time[i]) for i in range(0 , 20)]

# %% [markdown]
# ### Ques 5

# %%
Image('/content/drive/MyDrive/MCSC-202-Numerical/q5.png')

# %%
1a = int(input('Enter the coefficient of x^2 : '))
b = int(input('Enter the coefficient of x : '))
c = int(input('Enter the constant term : '))

det = b**2 - 4* a *c


if(det == 0):
  print('The roots are identical and equal to ', (-b)/(2 * a))

elif(det > 0):
  print('There are two real roots ' , (-b + np.sqrt(det))/(2 * a) , 'and ' , (-b - np.sqrt(det))/(2 * a) ,'.')

else:
  print('There are two complex roots' , (-b/2*a) , '+/-', np.sqrt(-det)/(2 * a) , 'i' )
# Out:
# Enter the coefficient of x^2 : 1
# Enter the coefficient of x :
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-f37a11da07f5> in <module>()
#       1 a = int(input('Enter the coefficient of x^2 : '))
# ----> 2 b = int(input('Enter the coefficient of x : '))
#       3 c = int(input('Enter the constant term : '))
#       4
#       5 det = b**2 - 4* a *c
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# 5
# ### Ques 6

# %%
Image('/content/drive/MyDrive/MCSC-202-Numerical/q6.png')

# %%
def fact_while(n):
  fact = 1
  i = 1
  while(i <= n):
    fact = fact * i
    i = i + 1
  return fact

def fact_for(n):
  fact = 1
  for i in range(1 , n+1):
    fact = fact * i
  return fact

data = [[i , fact_while(i) , fact_for(i)] for i in range(0,6)]
print(tabulate(data , headers=['Num' , 'fact_while' , 'fact_for']))
# Out:
#   Num    fact_while    fact_for
# -----  ------------  ----------
#     0             1           1
#     1             1           1
#     2             2           2
#     3             6           6
#     4            24          24
#     5           120         120

# %% [markdown]
# ### Ques 7

# %%
Image('/content/drive/MyDrive/MCSC-202-Numerical/q7.png')

# %%
n = int(input('Enter a positive number'))
sum = 0
for i in range(1 , n + 1):
  sum = sum + i 
print('The sum of ', n , 'natural numbers is' , sum)
# Out:
# Enter a positive number4
# The sum of  4 natural numbers is 10

# %%
def sumN_loop(n):
  sum = 0
  for i in range(1 , n + 1):
      sum = sum + i 
  return sum

# %%
def sumN_formula(n):
  return n* (n+1) / 2

k = 10
print('The sum of numbers upto ' , k , ' is ', int(sumN_formula(k)))
# Out:
# The sum of numbers upto  10  is  55

# %%
data = [[i , sumN_loop(i) , sumN_formula(i)] for i in range(0,6)]
print(tabulate(data , headers=['Num' , 'sumN_loop' , 'sumN_formula']))
# Out:
#   Num    sumN_loop    sumN_formula
# -----  -----------  --------------
#     0            0               0
#     1            1               1
#     2            3               3
#     3            6               6
#     4           10              10
#     5           15              15

# %% [markdown]
# ### Ques 8

# %%
Image('/content/drive/MyDrive/MCSC-202-Numerical/q8.png')

# %%
n = int(input('Enter a positive number'))
sum = 0
for i in range(1 , n + 1):
  sum = sum + i**2 
print('The sum of square of', n , 'natural numbers is' , sum)
# Out:
# Enter a positive number5
# The sum of square of 5 natural numbers is 55

# %%
def sumNsq_loop(n):
  sum = 0
  for i in range(1 , n + 1):
      sum = sum + i**2 
  return sum

# %%
def sumNsq_formula(n):
  return n* (n+1) * (2*n + 1) / 6

k = 5
print('The sum of numbers upto ' , k , ' is ', int(sumNsq_formula(k)))
# Out:
# The sum of numbers upto  5  is  55

# %%
data = [[i , sumNsq_loop(i) , sumNsq_formula(i)] for i in range(0,6)]
print(tabulate(data , headers=['Num' , 'sumNsq_loop' , 'sumNsq_formula']))
# Out:
#   Num    sumNsq_loop    sumNsq_formula
# -----  -------------  ----------------
#     0              0                 0
#     1              1                 1
#     2              5                 5
#     3             14                14
#     4             30                30
#     5             55                55

# %% [markdown]
# ###Ques 9

# %%
Image('/content/drive/MyDrive/MCSC-202-Numerical/q9.png')

# %%
n = 1
while(3**n < 2000):
  n = n + 1
print('The integer is ' , n)
# Out:
# The integer is  7

# %% [markdown]
# ###Ques 10

# %%
Image('/content/drive/MyDrive/MCSC-202-Numerical/q10.png')

# %%
x = np.linspace(-3,3,100)
y = 3*x**2

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('zero')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

# plot the function
plt.plot(x,y, 'r')

# show the plot
plt.show()

# %% [markdown]
# ###Ques 11

# %%
Image('/content/drive/MyDrive/MCSC-202-Numerical/q11.png')

# %%
x = np.linspace(-2*np.pi, 2 * np.pi,100)
y1 = np.sin(x)
y2 = np.cos(x)

fig = plt.figure(figsize=(12, 6))
ax = fig.add_subplot(1, 1, 1)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('center')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

# plot the function
plt.plot(x,y1, 'r' , label = 'sine')
plt.plot(x,y2, 'b' , label = 'cosine')

plt.legend(loc="upper left")

# show the plot
plt.show()

# %% [markdown]
# ###Ques 12

# %%
Image('/content/drive/MyDrive/MCSC-202-Numerical/q12.png')

# %%
th = np.linspace(0 , 20 * np.pi , 1000)
x = 2 * th * np.cos(th)
y = 2 * th * np.sin(th)
z = 1 + 2 * th

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.set_title("Parametic plot in 3d")

ax.set_xlabel("x")

ax.set_ylabel("y")

ax.set_zlabel("z")
plt.plot(x,y,z)

# %% [markdown]
# ###Ques 13

# %%
Image('/content/drive/MyDrive/MCSC-202-Numerical/q13.png')

# %%
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})

# Make data.
X = np.arange(-3, 3, 0.25)
Y = np.arange(-3, 3, 0.25)
X, Y = np.meshgrid(X, Y)
Z = (1 - 0.5 * X+ X**5 + Y**5) / math.e**(-X*X-Y*Y)


# Plot the surface.
surf = ax.plot_surface(X, Y, Z)

# %%
xlist = np.linspace(-3.0, 3.0, 100)
ylist = np.linspace(-3.0, 3.0, 100)
X, Y = np.meshgrid(xlist, ylist)
Z = (1 - (X/2) + X**5 + Y**5)/(np.e**(-X**2-Y**2))
fig,ax=plt.subplots(1,1)
cp = ax.contourf(X, Y, Z)
fig.colorbar(cp) # Add a colorbar to a plot
ax.set_title('Filled Contours Plot')
ax.set_xlabel('x')
ax.set_ylabel('y')
plt.show()
